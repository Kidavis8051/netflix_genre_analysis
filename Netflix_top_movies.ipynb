# %%
import pandas as pd

# Load your Netflix CSV file
df = pd.read_csv('netflix_titles.csv')

# Preview the data
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
from IPython.display import display, Markdown

# --- Top 10 International Movies ---
display(Markdown("### 🎬 Top 10 International Movies"))
display(top_10_international[['title', 'listed_in']].reset_index(drop=True))

# --- Top 5 Drama Movies ---
display(Markdown("### 🎭 Top 5 Drama Movies"))
display(top_5_dramas[['title', 'listed_in']].reset_index(drop=True))

# --- Top 5 Comedy Movies ---
display(Markdown("### 😂 Top 5 Comedy Movies"))
display(top_5_comedies[['title', 'listed_in']].reset_index(drop=True))
# Out:
# ### 🎬 Top 10 International Movies
#                                                title  \
# 0                                            Sankofa
# 1                                       Je Suis Karl
# 2  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 3                                    Avvai Shanmughi
# 4                                              Jeans
# 5                                     Minsara Kanavu
# 6                                    Ankahi Kahaniya
# 7                     The Father Who Moves Mountains
# 8                                     The Stronghold
# 9  InuYasha the Movie 2: The Castle Beyond the Lo...
#
#                                            listed_in
# 0   Dramas, Independent Movies, International Movies
# 1                       Dramas, International Movies
# 2                Documentaries, International Movies
# 3                     Comedies, International Movies
# 4    Comedies, International Movies, Romantic Movies
# ...
